# %% [markdown]
# <a href="https://colab.research.google.com/github/marqueserick/ciencia-dados/blob/main/01_introducao_ao_python/04_dicionario_set_tupla.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#conjunto de chave e valor
eu = {"nome": "Erick", "idade": 26, "cargo":"Analista Desenvolvedor"}
print(eu)
# Out:
# {'nome': 'Erick', 'idade': 26, 'cargo': 'Analista Desenvolvedor'}

# %%
#set é um conjunto não ordenado e não repetido de elementos
animais  =  {"gato","cachorro","papagaio"}
animais.add("cachorro")
print(animais)
# Out:
# {'papagaio', 'gato', 'cachorro'}

# %%
#tupla é um conjunto imutavel de elementos
tp = (1,2,6,5)
print(tp)
# Out:
# (1, 2, 6, 5)
