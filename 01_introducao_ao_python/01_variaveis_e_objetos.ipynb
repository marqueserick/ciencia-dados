# %% [markdown]
# <a href="https://colab.research.google.com/github/marqueserick/ciencia-dados/blob/main/01_introducao_ao_python/01_variaveis_e_objetos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Formação Cientista de Dados - Erick Marques
# Variáveis e Objetos

# %%
#Cria variável do tipo inteiro
x = 1
print(x)
#Cria variável do tipo float
y = 3.13
print(y)
#Cria variável do tipo string
m = "Python"
m = 'Python'
print(m)
#Cria variável do tipo lógica
w = True  
y = False
print(y)
# Out:
# 1
# 3.13
# Python
# False

# %%
#calculadora
x = 10
y = 20
z = 100
w = (x + y) * z / 100
print(w)
# Out:
# 30.0

# %%
#exibir texto no console
print("Este texto será impresso no console")
print(x)
print("Texto e duas variáveis: ", x ,", ", z)
# Out:
# Este texto será impresso no console
# 10
# Texto e duas variáveis:  10 ,  100

# %%
#verificar tipo
print(type(x))
print(type(m))
# Out:
# <class 'int'>
# <class 'str'>

# %%
#entrada de dados
print("Informe o valor: ")
i = input()
#mostra tipo string
print(type(i))
# Out:
# Informe o valor:
# 10
# <class 'str'>

# %%
#entrada de valor com msg separada e junto
print("Informe o valor: ")
i = input()
# ou
i = input("Informe o valor: ")
# Out:
# Informe o valor:
# 9
# Informe o valor: 0

# %%
#conversão de valores
#para inteiro
var = input("Informe o valor: ")
print(type(var))
var = int(var)
print(type(var))
# Out:
# Informe o valor: 8
# <class 'str'>
# <class 'int'>

# %%
#para float
var = input("Informe o valor: ")
print(type(var))
var = float(var)
print(type(var))
# Out:
# Informe o valor: 7
# <class 'str'>
# <class 'float'>

# %%
# Este texto é um comentário
X = 10  # a partir daqui é um comentário
