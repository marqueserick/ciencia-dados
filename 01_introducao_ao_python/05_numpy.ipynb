# %% [markdown]
# <a href="https://colab.research.google.com/github/marqueserick/_ciencia-dados/blob/main/01_introducao_ao_python/05_numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#facilita operaçoes matematicas
#objeto de matriz multidimensional
#possui tamanho fixo e todos elementos devem ter o mesmo tipo
import numpy as np
a = np.array([12,36,5,7,5])
print(a)
print(a.dtype)
# Out:
# [12 36  5  7  5]
# int64
