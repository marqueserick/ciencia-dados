# %% [markdown]
# <a href="https://colab.research.google.com/github/marqueserick/ciencia-dados/blob/main/01_introducao_ao_python/02_estrutura_decisao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Formação Cientista de Dados - Erick Marques
# Estruturas de Decisão

# %%
nota = 7
if nota >= 7:
	print("Aprovado")
	print("Parabéns!")
else:
	print("Reprovado")

# %%
#mudar o valor da variável
nota = 5
if nota >= 7:
	print("Aprovado")
else:
	print("Reprovado")

# %%
#Testar com 4,5 e 7
nota = 7
if nota <= 4:
	print("Reprovado")
elif nota > 4 and nota <=6:
	print("Exame")
else:
	print("Aprovado")
