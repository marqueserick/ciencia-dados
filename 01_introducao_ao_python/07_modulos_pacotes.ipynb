# %% [markdown]
# <a href="https://colab.research.google.com/github/marqueserick/_ciencia-dados/blob/main/01_introducao_ao_python/07_modulos_pacotes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#conjunto de funcionalidades organizadas em arquivos
#usamos import para acessar os arquivos
# palavra reservada 'as' dá um apelido para o import
#apos importar podemos usar as funcoes do modulo

import statistics as stat
z = [6,5,9,8,3]
x = stat.median(z)
y = stat.mean(z)
print(f"Mediana {x}\nMédia {y}")
# Out:
# Mediana 6
# Média 6.2
