# %% [markdown]
# <a href="https://colab.research.google.com/github/marqueserick/ciencia-dados/blob/main/01_introducao_ao_python/06_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#permite tratar dados tabulares
#permite dados  de tipos diferentes em diferentes colunas
#2 objetos principais: data frame e series
#data frame é como uma tabela de banco de dados
#series são dados em serie, como uma linha do dataframe
import pandas as pd
csv = 'https://raw.githubusercontent.com/marqueserick/_ciencia-dados/main/01_introducao_ao_python/00_dados/Credit.csv'
dados = pd.read_csv(csv)
dados
# Out:
#     checking_status  duration                    credit_history  \
# 0                <0         6  'critical/other existing credit'
# 1          0<=X<200        48                   'existing paid'
# 2     'no checking'        12  'critical/other existing credit'
# 3                <0        42                   'existing paid'
# 4                <0        24              'delayed previously'
# ..              ...       ...                               ...
# 995   'no checking'        12                   'existing paid'
# 996              <0        30                   'existing paid'
# 997   'no checking'        12                   'existing paid'
# 998              <0        45                   'existing paid'
# 999        0<=X<200        45  'critical/other existing credit'
#
#                  purpose  credit_amount      savings_status  employment  \
# 0               radio/tv           1169  'no known savings'         >=7
# ...

# %%
dados.shape
# Out:
# (1000, 21)

# %%
dados.describe()
# Out:
#           duration  credit_amount  installment_commitment  residence_since  \
# count  1000.000000    1000.000000             1000.000000      1000.000000
# mean     20.903000    3271.258000                2.973000         2.845000
# std      12.058814    2822.736876                1.118715         1.103718
# min       4.000000     250.000000                1.000000         1.000000
# 25%      12.000000    1365.500000                2.000000         2.000000
# 50%      18.000000    2319.500000                3.000000         3.000000
# 75%      24.000000    3972.250000                4.000000         4.000000
# max      72.000000   18424.000000                4.000000         4.000000
#
#                age  existing_credits  num_dependents
# count  1000.000000       1000.000000     1000.000000
# mean     35.546000          1.407000        1.155000
# std      11.375469          0.577654        0.362086
# min      19.000000          1.000000        1.000000
# ...

# %%
#retorna os 5 primeiros dados da tabela
#pode retorna n valores passados por parametro
dados.head()
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# ...

# %%
dados.head(8)
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
# 5   'no checking'        36                   'existing paid'
# 6   'no checking'        24                   'existing paid'
# 7        0<=X<200        36                   'existing paid'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# ...

# %%
#ultimos dados da tabela
dados.tail()
# Out:
#     checking_status  duration                    credit_history  \
# 995   'no checking'        12                   'existing paid'
# 996              <0        30                   'existing paid'
# 997   'no checking'        12                   'existing paid'
# 998              <0        45                   'existing paid'
# 999        0<=X<200        45  'critical/other existing credit'
#
#                  purpose  credit_amount savings_status  employment  \
# 995  furniture/equipment           1736           <100      4<=X<7
# 996           'used car'           3857           <100      1<=X<4
# 997             radio/tv            804           <100         >=7
# 998             radio/tv           1845           <100      1<=X<4
# 999           'used car'           4576     100<=X<500  unemployed
#
#      installment_commitment       personal_status other_parties  ...  \
# 995                       3  'female div/dep/mar'          none  ...
# ...

# %%
dados.tail(2)
# Out:
#     checking_status  duration                    credit_history     purpose  \
# 998              <0        45                   'existing paid'    radio/tv
# 999        0<=X<200        45  'critical/other existing credit'  'used car'
#
#      credit_amount savings_status  employment  installment_commitment  \
# 998           1845           <100      1<=X<4                       4
# 999           4576     100<=X<500  unemployed                       3
#
#     personal_status other_parties  ...   property_magnitude age  \
# 998   'male single'          none  ...  'no known property'  23
# 999   'male single'          none  ...                  car  27
#
#      other_payment_plans     housing existing_credits      job num_dependents  \
# 998                 none  'for free'                1  skilled              1
# 999                 none         own                1  skilled              1
#
#      own_telephone foreign_worker class
# 998            yes            yes   bad
# ...

# %%
#selecionar um coluna da tabela
dados[["duration"]]
# Out:
#      duration
# 0           6
# 1          48
# 2          12
# 3          42
# 4          24
# ..        ...
# 995        12
# 996        30
# 997        12
# 998        45
# 999        45
#
# [1000 rows x 1 columns]

# %%
#filtrar linhas por indice
dados.loc[1:3] #segunda, terceira e quarta linhas
# Out:
#   checking_status  duration                    credit_history  \
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
#
#                purpose  credit_amount savings_status employment  \
# 1             radio/tv           5951           <100     1<=X<4
# 2            education           2096           <100     4<=X<7
# 3  furniture/equipment           7882           <100     4<=X<7
#
#    installment_commitment       personal_status other_parties  ...  \
# 1                       2  'female div/dep/mar'          none  ...
# 2                       2         'male single'          none  ...
# 3                       2         'male single'     guarantor  ...
#
#    property_magnitude age  other_payment_plans     housing existing_credits  \
# 1       'real estate'  22                 none         own                1
# ...

# %%
#selecionar linhas especificas
dados.loc[[1,3]]
# Out:
#   checking_status  duration   credit_history              purpose  \
# 1        0<=X<200        48  'existing paid'             radio/tv
# 3              <0        42  'existing paid'  furniture/equipment
#
#    credit_amount savings_status employment  installment_commitment  \
# 1           5951           <100     1<=X<4                       2
# 3           7882           <100     4<=X<7                       2
#
#         personal_status other_parties  ...  property_magnitude age  \
# 1  'female div/dep/mar'          none  ...       'real estate'  22
# 3         'male single'     guarantor  ...    'life insurance'  45
#
#    other_payment_plans     housing existing_credits      job num_dependents  \
# 1                 none         own                1  skilled              1
# 3                 none  'for free'                1  skilled              2
#
#    own_telephone foreign_worker class
# 1           none            yes   bad
# 3           none            yes  good
#
# ...

# %%
#selecionar linhas com condição
dados.loc[dados['purpose']== "radio/tv"]
# Out:
#     checking_status  duration                    credit_history   purpose  \
# 0                <0         6  'critical/other existing credit'  radio/tv
# 1          0<=X<200        48                   'existing paid'  radio/tv
# 8     'no checking'        12                   'existing paid'  radio/tv
# 12         0<=X<200        12                   'existing paid'  radio/tv
# 15               <0        24                   'existing paid'  radio/tv
# ..              ...       ...                               ...       ...
# 989        0<=X<200        24  'critical/other existing credit'  radio/tv
# 991   'no checking'        15                        'all paid'  radio/tv
# 992              <0        18                   'existing paid'  radio/tv
# 997   'no checking'        12                   'existing paid'  radio/tv
# 998              <0        45                   'existing paid'  radio/tv
#
#      credit_amount      savings_status employment  installment_commitment  \
# ...

# %%
#outro filtro
dados.loc[dados['credit_amount']>18000]
# Out:
#     checking_status  duration         credit_history purpose  credit_amount  \
# 915        0<=X<200        48  'no credits/all paid'   other          18424
#
#     savings_status employment  installment_commitment       personal_status  \
# 915           <100     1<=X<4                       1  'female div/dep/mar'
#
#     other_parties  ...  property_magnitude age  other_payment_plans housing  \
# 915          none  ...    'life insurance'  32                 bank     own
#
#     existing_credits                          job num_dependents  \
# 915                1  'high qualif/self emp/mgmt'              1
#
#      own_telephone foreign_worker class
# 915            yes             no   bad
#
# [1 rows x 21 columns]

# %%
#criar dataframe
credito2 = dados.loc[dados['credit_amount']>18000]
credito2
# Out:
#     checking_status  duration         credit_history purpose  credit_amount  \
# 915        0<=X<200        48  'no credits/all paid'   other          18424
#
#     savings_status employment  installment_commitment       personal_status  \
# 915           <100     1<=X<4                       1  'female div/dep/mar'
#
#     other_parties  ...  property_magnitude age  other_payment_plans housing  \
# 915          none  ...    'life insurance'  32                 bank     own
#
#     existing_credits                          job num_dependents  \
# 915                1  'high qualif/self emp/mgmt'              1
#
#      own_telephone foreign_worker class
# 915            yes             no   bad
#
# [1 rows x 21 columns]

# %%
#definindo somente algumas colunas
credito3 = dados[['checking_status','duration']].loc[dados['credit_amount']>18000]
credito3
# Out:
#     checking_status  duration
# 915        0<=X<200        48

# %%
#series, coluna unica
#pode ser criada a partir de listas, array de numpy ou coluna do df
pares = pd.Series([2,4,6,8,10,12,14])
pares
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# 5    12
# 6    14
# dtype: int64

# %%
#serie a partir de um array de numpy
import numpy as np
array_impares = np.array([1,3,5,7,9,11])
impares = pd.Series(array_impares)
impares
# Out:
# 0     1
# 1     3
# 2     5
# 3     7
# 4     9
# 5    11
# dtype: int64

# %%
#series a partir de um coluna do dataframe
purpose = dados['purpose']
purpose
# Out:
# 0                 radio/tv
# 1                 radio/tv
# 2                education
# 3      furniture/equipment
# 4                'new car'
#               ...
# 995    furniture/equipment
# 996             'used car'
# 997               radio/tv
# 998               radio/tv
# 999             'used car'
# Name: purpose, Length: 1000, dtype: object

# %%
purpose_df = dados[['purpose']]
purpose_df
# Out:
#                  purpose
# 0               radio/tv
# 1               radio/tv
# 2              education
# 3    furniture/equipment
# 4              'new car'
# ..                   ...
# 995  furniture/equipment
# 996           'used car'
# 997             radio/tv
# 998             radio/tv
# 999           'used car'
#
# [1000 rows x 1 columns]

# %%
print(type(purpose))
print(type(purpose_df))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
#renomear colunas
dados.rename(columns={"duration":"duracao","purpose":"proposito"})
# Out:
#     checking_status  duracao                    credit_history  \
# 0                <0        6  'critical/other existing credit'
# 1          0<=X<200       48                   'existing paid'
# 2     'no checking'       12  'critical/other existing credit'
# 3                <0       42                   'existing paid'
# 4                <0       24              'delayed previously'
# ..              ...      ...                               ...
# 995   'no checking'       12                   'existing paid'
# 996              <0       30                   'existing paid'
# 997   'no checking'       12                   'existing paid'
# 998              <0       45                   'existing paid'
# 999        0<=X<200       45  'critical/other existing credit'
#
#                proposito  credit_amount      savings_status  employment  \
# 0               radio/tv           1169  'no known savings'         >=7
# ...

# %%
dados.head(1)
# Out:
#   checking_status  duration                    credit_history   purpose  \
# 0              <0         6  'critical/other existing credit'  radio/tv
#
#    credit_amount      savings_status employment  installment_commitment  \
# 0           1169  'no known savings'        >=7                       4
#
#   personal_status other_parties  ...  property_magnitude age  \
# 0   'male single'          none  ...       'real estate'  67
#
#    other_payment_plans housing existing_credits      job num_dependents  \
# 0                 none     own                2  skilled              1
#
#    own_telephone foreign_worker class
# 0            yes            yes  good
#
# [1 rows x 21 columns]

# %%
dados.rename(columns={"duration":"duracao", "purpose":"proposito"}, inplace = True)

# %%
dados.head(1)
# Out:
#   checking_status  duracao                    credit_history proposito  \
# 0              <0        6  'critical/other existing credit'  radio/tv
#
#    credit_amount      savings_status employment  installment_commitment  \
# 0           1169  'no known savings'        >=7                       4
#
#   personal_status other_parties  ...  property_magnitude age  \
# 0   'male single'          none  ...       'real estate'  67
#
#    other_payment_plans housing existing_credits      job num_dependents  \
# 0                 none     own                2  skilled              1
#
#    own_telephone foreign_worker class
# 0            yes            yes  good
#
# [1 rows x 21 columns]

# %%
#excluir um coluna
dados.drop('checking_status',axis=1,inplace=True)
dados
# Out:
#      duracao                    credit_history            proposito  \
# 0          6  'critical/other existing credit'             radio/tv
# 1         48                   'existing paid'             radio/tv
# 2         12  'critical/other existing credit'            education
# 3         42                   'existing paid'  furniture/equipment
# 4         24              'delayed previously'            'new car'
# ..       ...                               ...                  ...
# 995       12                   'existing paid'  furniture/equipment
# 996       30                   'existing paid'           'used car'
# 997       12                   'existing paid'             radio/tv
# 998       45                   'existing paid'             radio/tv
# 999       45  'critical/other existing credit'           'used car'
#
#      credit_amount      savings_status  employment  installment_commitment  \
# ...

# %%
dados.head(1)
# Out:
#    duracao                    credit_history proposito  credit_amount  \
# 0        6  'critical/other existing credit'  radio/tv           1169
#
#        savings_status employment  installment_commitment personal_status  \
# 0  'no known savings'        >=7                       4   'male single'
#
#   other_parties  residence_since property_magnitude  age other_payment_plans  \
# 0          none                4      'real estate'   67                none
#
#   housing  existing_credits      job  num_dependents own_telephone  \
# 0     own                 2  skilled               1           yes
#
#   foreign_worker class
# 0            yes  good

# %%
#verifica dados nulos
dados.isnull()
# Out:
#      duracao  credit_history  proposito  credit_amount  savings_status  \
# 0      False           False      False          False           False
# 1      False           False      False          False           False
# 2      False           False      False          False           False
# 3      False           False      False          False           False
# 4      False           False      False          False           False
# ..       ...             ...        ...            ...             ...
# 995    False           False      False          False           False
# 996    False           False      False          False           False
# 997    False           False      False          False           False
# 998    False           False      False          False           False
# 999    False           False      False          False           False
#
#      employment  installment_commitment  personal_status  other_parties  \
# ...

# %%
#verificar dados nulos
dados.isnull().sum()
# Out:
# duracao                   0
# credit_history            0
# proposito                 0
# credit_amount             0
# savings_status            0
# employment                0
# installment_commitment    0
# personal_status           0
# other_parties             0
# residence_since           0
# property_magnitude        0
# age                       0
# other_payment_plans       0
# housing                   0
# existing_credits          0
# job                       0
# num_dependents            0
# own_telephone             0
# foreign_worker            0
# class                     0
# dtype: int64

# %%
#retirar colunas com NaN
dados.dropna()
# Out:
#      duracao                    credit_history            proposito  \
# 0          6  'critical/other existing credit'             radio/tv
# 1         48                   'existing paid'             radio/tv
# 2         12  'critical/other existing credit'            education
# 3         42                   'existing paid'  furniture/equipment
# 4         24              'delayed previously'            'new car'
# ..       ...                               ...                  ...
# 995       12                   'existing paid'  furniture/equipment
# 996       30                   'existing paid'           'used car'
# 997       12                   'existing paid'             radio/tv
# 998       45                   'existing paid'             radio/tv
# 999       45  'critical/other existing credit'           'used car'
#
#      credit_amount      savings_status  employment  installment_commitment  \
# ...

# %%
#preencher dados faltantes
dados['duracao'].fillna(0,inplace= True)

# %%
#iloc
#selecionar intervalo [linha inicio : linha fim(nao inclui) ,
# coluna inicio: coluna fim(nao inclui)]
dados.iloc[0:3,0:5]
# Out:
#    duracao                    credit_history  proposito  credit_amount  \
# 0        6  'critical/other existing credit'   radio/tv           1169
# 1       48                   'existing paid'   radio/tv           5951
# 2       12  'critical/other existing credit'  education           2096
#
#        savings_status
# 0  'no known savings'
# 1                <100
# 2                <100

# %%
#selecionando linhas especificas
dados.iloc[[0,1,2,3,7],0:5]
# Out:
#    duracao                    credit_history            proposito  \
# 0        6  'critical/other existing credit'             radio/tv
# 1       48                   'existing paid'             radio/tv
# 2       12  'critical/other existing credit'            education
# 3       42                   'existing paid'  furniture/equipment
# 7       36                   'existing paid'           'used car'
#
#    credit_amount      savings_status
# 0           1169  'no known savings'
# 1           5951                <100
# 2           2096                <100
# 3           7882                <100
# 7           6948                <100
