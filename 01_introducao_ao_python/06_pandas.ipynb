# %% [markdown]
# <a href="https://colab.research.google.com/github/marqueserick/_ciencia-dados/blob/main/01_introducao_ao_python/06_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#permite tratar dados tabulares
#permite dados  de tipos diferentes em diferentes colunas
#2 objetos principais: data frame e series
#data frame é como uma tabela de banco de dados
#series são dados em serie, como uma linha do dataframe
import pandas as pd
csv = 'https://raw.githubusercontent.com/marqueserick/_ciencia-dados/main/01_introducao_ao_python/00_dados/Credit.csv'
dados = pd.read_csv(csv)
dados
# Out:
#     checking_status  duration                    credit_history  \
# 0                <0         6  'critical/other existing credit'
# 1          0<=X<200        48                   'existing paid'
# 2     'no checking'        12  'critical/other existing credit'
# 3                <0        42                   'existing paid'
# 4                <0        24              'delayed previously'
# ..              ...       ...                               ...
# 995   'no checking'        12                   'existing paid'
# 996              <0        30                   'existing paid'
# 997   'no checking'        12                   'existing paid'
# 998              <0        45                   'existing paid'
# 999        0<=X<200        45  'critical/other existing credit'
#
#                  purpose  credit_amount      savings_status  employment  \
# 0               radio/tv           1169  'no known savings'         >=7
# ...
